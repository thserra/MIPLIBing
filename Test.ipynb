# %%
from MIPLIBing import MIPLIBing
from MIPLIBing import Libraries

#mip = MIPLIBing(library = Libraries.MINLPLIB, verbose = True, update_csv = True, file_extension="lp")
#instances = mip.get_instances(min_var=100, max_var=100, problem_type="QP")
#mip = MIPLIBing(library = Libraries.MIPLIB2017_Collection, verbose = True, update_csv = True)
#instances = mip.get_instances(min_var=100, max_var=100)
mip = MIPLIBing(library = Libraries.QPLIB, verbose = True, update_csv = True, file_extension="lp")
instances = mip.get_instances(min_var=100, max_var=100)
print()
for instance in instances:
    print(instance)
# Out:
# ...
# Instance 0032: Downloading from http://qplib.zib.de/lp/QPLIB_0032.lp
# Instance 2512: Downloading from http://qplib.zib.de/lp/QPLIB_2512.lp
# Instance 5935: Downloading from http://qplib.zib.de/lp/QPLIB_5935.lp
# Instance 5944: Downloading from http://qplib.zib.de/lp/QPLIB_5944.lp
#
# Instance:              	0032
# Objective Density:     	99.9%
# Problematic EV Density:	25.0%
# Objective Type:        	Q
# Variables Type:        	Q
# Constraints Type:      	Q
# Local path:            	MIPLIBing_cache/QPLIB/QPLIB_0032.lp
# Feasible:              	Yes
# Primal Bound:          	10.12639121
# Dual Bound:            	None
# Status:                	None
# Variables:             	100	(50 binary)	 (0 integer)	 (50 continuous)
# Constraints:           	52	(0 quadratic)
# Non-zeroes:            	250
#
#
# Instance:              	2512
# Objective Density:     	77.4%
# Problematic EV Density:	46.0%
# Objective Type:        	Q
# Variables Type:        	Q
# Constraints Type:      	Q
# ...

# %%
mip = MIPLIBing(library = Libraries.MIPLIB2017_Collection, verbose = True, update_csv = True)
instances = mip.get_instances(min_var=80, max_var=100)
print()
for instance in instances:
    print(instance)
# Out:
# ...
# Instance pk1: Downloading from http://miplib.zib.de/WebData/instances/pk1.mps.gz
# Instance p2m2p1m1p0n100: Already downloaded
# Instance b-ball: Already downloaded
#
# Instance:              	pk1
# Type:                  	MILP
# Local path:            	MIPLIBing_cache/MIPLIB2017_Collection/pk1.mps
# Feasible:              	Yes
# Primal Bound:          	11.0
# Dual Bound:            	None
# Status:                	easy
# Variables:             	86	(55 binary)	 (0 integer)	 (31 continuous)
# Constraints:           	45
# Non-zeroes:            	915
#
#
# Instance:              	p2m2p1m1p0n100
# Type:                  	MILP
# Local path:            	MIPLIBing_cache/MIPLIB2017_Collection/p2m2p1m1p0n100.mps
# Feasible:              	No
# Primal Bound:          	None
# Dual Bound:            	None
# Status:                	easy
# Variables:             	100	(100 binary)	 (0 integer)	 (0 continuous)
# Constraints:           	1
# Non-zeroes:            	100
#
#
# ...
